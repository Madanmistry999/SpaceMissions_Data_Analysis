# %% [markdown]
# <Font size='4'>**Importing required libraries**</Font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <Font size='4'>**Reading CSV Files**</Font>

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df=pd.read_csv('./space_missions.csv',encoding_errors='ignore')
df
# Out:
#         Company                                         Location        Date  \
# 0     RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-10-04
# 1     RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-11-03
# 2       US Navy         LC-18A, Cape Canaveral AFS, Florida, USA  1957-12-06
# 3          AMBA         LC-26A, Cape Canaveral AFS, Florida, USA  1958-02-01
# 4       US Navy         LC-18A, Cape Canaveral AFS, Florida, USA  1958-02-05
# ...         ...                                              ...         ...
# 4625     SpaceX          SLC-4E, Vandenberg SFB, California, USA  2022-07-22
# 4626       CASC  LC-101, Wenchang Satellite Launch Center, China  2022-07-24
# 4627     SpaceX       LC-39A, Kennedy Space Center, Florida, USA  2022-07-24
# 4628  CAS Space           Jiuquan Satellite Launch Center, China  2022-07-27
# 4629       CASC     LC-3, Xichang Satellite Launch Center, China  2022-07-29
#
#           Time            Rocket              Mission RocketStatus  Price  \
# 0     19:28:00    Sputnik 8K71PS            Sputnik-1      Retired    NaN
# 1     02:30:00    Sputnik 8K71PS            Sputnik-2      Retired    NaN
# 2     16:44:00          Vanguard         Vanguard TV3      Retired    NaN
# 3     03:48:00            Juno I           Explorer 1      Retired    NaN
# 4     07:33:00          Vanguard       Vanguard TV3BU      Retired    NaN
# ...        ...               ...                  ...          ...    ...
# 4625  17:39:00  Falcon 9 Block 5   Starlink Group 3-2       Active     67
# 4626  06:22:00     Long March 5B              Wentian       Active    NaN
# 4627  13:38:00  Falcon 9 Block 5  Starlink Group 4-25       Active     67
# 4628  04:12:00        Zhongke-1A          Demo Flight       Active    NaN
# 4629  13:28:00     Long March 2D   Yaogan 35 Group 03       Active  29.75
#
#      MissionStatus
# 0          Success
# 1          Success
# 2          Failure
# 3          Success
# 4          Failure
# ...            ...
# 4625       Success
# 4626       Success
# 4627       Success
# 4628       Success
# 4629       Success
#
# [4630 rows x 9 columns]

# %% [markdown]
# <font size='7'>**Recommended Analysis**</font>
#
# <font size='4'>
#
# How have rocket launches trended across time? Has mission success rate increased?
#
# Which countries have had the most successful space missions? Has it always been that way?
#
# Which rocket has been used for the most space missions? Is it still active?
#
# Are there any patterns you can notice with the launch locations?
# </font>

# %% [markdown]
# # Q.1: Data Cleansing <a id=0></a>

# %%
#chacking for null  values present in dataset or not
df[df.isnull().any(axis=1)]
# Out:
#          Company                                           Location  \
# 0      RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 1      RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 2        US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 3           AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4        US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# ...          ...                                                ...
# 4605        KARI               LC-2, Naro Space Center, South Korea
# 4610  Rocket Lab     Rocket Lab LC-1B, Māhia Peninsula, New Zealand
# 4621         ESA  ELV-1, Guiana Space Centre, French Guiana, France
# 4626        CASC    LC-101, Wenchang Satellite Launch Center, China
# 4628   CAS Space             Jiuquan Satellite Launch Center, China
#
#             Date      Time           Rocket             Mission RocketStatus  \
# 0     1957-10-04  19:28:00   Sputnik 8K71PS           Sputnik-1      Retired
# 1     1957-11-03  02:30:00   Sputnik 8K71PS           Sputnik-2      Retired
# 2     1957-12-06  16:44:00         Vanguard        Vanguard TV3      Retired
# 3     1958-02-01  03:48:00           Juno I          Explorer 1      Retired
# 4     1958-02-05  07:33:00         Vanguard      Vanguard TV3BU      Retired
# ...          ...       ...              ...                 ...          ...
# 4605  2022-06-21  07:00:00           KSLV-2       Test Flight 2       Active
# 4610  2022-06-28  09:55:00  Electron/Photon            CAPSTONE       Active
# 4621  2022-07-13  13:13:00           Vega C  LARES 2 & Cubesats       Active
# 4626  2022-07-24  06:22:00    Long March 5B             Wentian       Active
# 4628  2022-07-27  04:12:00       Zhongke-1A         Demo Flight       Active
#
#      Price MissionStatus
# 0      NaN       Success
# 1      NaN       Success
# 2      NaN       Failure
# 3      NaN       Success
# 4      NaN       Failure
# ...    ...           ...
# 4605   NaN       Success
# 4610   NaN       Success
# 4621   NaN       Success
# 4626   NaN       Success
# 4628   NaN       Success
#
# [3371 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4630 entries, 0 to 4629
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        4630 non-null   object
#  1   Location       4630 non-null   object
#  2   Date           4630 non-null   object
#  3   Time           4503 non-null   object
#  4   Rocket         4630 non-null   object
#  5   Mission        4630 non-null   object
#  6   RocketStatus   4630 non-null   object
#  7   Price          1265 non-null   object
#  8   MissionStatus  4630 non-null   object
# dtypes: object(9)
# memory usage: 325.7+ KB

# %%
df[df['Time'].isnull()]
# Out:
#           Company                                           Location  \
# 13        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 15        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 17        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 19        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 20        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# ...           ...                                                ...
# 3988          ISA  Imam Khomeini Spaceport, Semnan Space Center, ...
# 4029  Blue Origin    Blue Origin Launch Site, West Texas, Texas, USA
# 4161          ISA  Imam Khomeini Spaceport, Semnan Space Center, ...
# 4217          ISA  Imam Khomeini Spaceport, Semnan Space Center, ...
# 4389          ISA   Launch Platform, Shahrud Missile Test Site, Iran
#
#             Date Time              Rocket       Mission RocketStatus Price  \
# 13    1958-07-25  NaN  NOTS-EV-1 Pilot II  Pilot-1 (D1)      Retired   NaN
# 15    1958-08-12  NaN  NOTS-EV-1 Pilot II  Pilot-2 (D2)      Retired   NaN
# 17    1958-08-22  NaN  NOTS-EV-1 Pilot II  Pilot-3 (D3)      Retired   NaN
# 19    1958-08-25  NaN  NOTS-EV-1 Pilot II  Pilot-4 (R1)      Retired   NaN
# 20    1958-08-26  NaN  NOTS-EV-1 Pilot II  Pilot-5 (R2)      Retired   NaN
# ...          ...  ...                 ...           ...          ...   ...
# 3988  2017-07-27  NaN             Simorgh   Test Flight       Active   NaN
# 4029  2017-12-17  NaN         New Shepard          NS-7       Active   NaN
# 4161  2019-02-05  NaN           Safir-1B+        Dousti       Active   NaN
# 4217  2019-08-29  NaN           Safir-1B+       Nahid-1       Active   NaN
# 4389  2021-02-01  NaN            Zoljanah   Demo Flight       Active   NaN
#
#           MissionStatus
# 13              Failure
# 15              Failure
# 17              Failure
# 19              Failure
# 20              Failure
# ...                 ...
# 3988            Failure
# 4029            Success
# 4161            Failure
# 4217  Prelaunch Failure
# 4389            Success
#
# [127 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# Company             0
# Location            0
# Date                0
# Time              127
# Rocket              0
# Mission             0
# RocketStatus        0
# Price            3365
# MissionStatus       0
# dtype: int64

# %%
#converting price column in int datatype
df['Price']=pd.to_numeric(df['Price'].str.replace(',',' '),errors='coerce')
df['Price']=df['Price'].astype(float)

#fill missing value with avg of price
df['Price']=df['Price'].fillna(df['Price'].mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4630 entries, 0 to 4629
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        4630 non-null   object
#  1   Location       4630 non-null   object
#  2   Date           4630 non-null   object
#  3   Time           4503 non-null   object
#  4   Rocket         4630 non-null   object
#  5   Mission        4630 non-null   object
#  6   RocketStatus   4630 non-null   object
#  7   Price          4630 non-null   float64
#  8   MissionStatus  4630 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 325.7+ KB

# %%
df.isna().sum()
# Out:
# Company            0
# Location           0
# Date               0
# Time             127
# Rocket             0
# Mission            0
# RocketStatus       0
# Price              0
# MissionStatus      0
# dtype: int64

# %%
#removing time column
df.drop(columns=['Time'],axis=0,inplace=True)

# %%
df['Date']=pd.to_datetime(df['Date'])
#df.info()

# %%
#extracting year from date column
df['MissionYear']=df['Date'].dt.year
df
# Out:
#         Company                                         Location       Date  \
# 0     RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan 1957-10-04
# 1     RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan 1957-11-03
# 2       US Navy         LC-18A, Cape Canaveral AFS, Florida, USA 1957-12-06
# 3          AMBA         LC-26A, Cape Canaveral AFS, Florida, USA 1958-02-01
# 4       US Navy         LC-18A, Cape Canaveral AFS, Florida, USA 1958-02-05
# ...         ...                                              ...        ...
# 4625     SpaceX          SLC-4E, Vandenberg SFB, California, USA 2022-07-22
# 4626       CASC  LC-101, Wenchang Satellite Launch Center, China 2022-07-24
# 4627     SpaceX       LC-39A, Kennedy Space Center, Florida, USA 2022-07-24
# 4628  CAS Space           Jiuquan Satellite Launch Center, China 2022-07-27
# 4629       CASC     LC-3, Xichang Satellite Launch Center, China 2022-07-29
#
#                 Rocket              Mission RocketStatus      Price  \
# 0       Sputnik 8K71PS            Sputnik-1      Retired  109.77956
# 1       Sputnik 8K71PS            Sputnik-2      Retired  109.77956
# 2             Vanguard         Vanguard TV3      Retired  109.77956
# 3               Juno I           Explorer 1      Retired  109.77956
# 4             Vanguard       Vanguard TV3BU      Retired  109.77956
# ...                ...                  ...          ...        ...
# 4625  Falcon 9 Block 5   Starlink Group 3-2       Active   67.00000
# 4626     Long March 5B              Wentian       Active  109.77956
# 4627  Falcon 9 Block 5  Starlink Group 4-25       Active   67.00000
# 4628        Zhongke-1A          Demo Flight       Active  109.77956
# 4629     Long March 2D   Yaogan 35 Group 03       Active   29.75000
#
#      MissionStatus      Country  MissionYear
# 0          Success   Kazakhstan         1957
# 1          Success   Kazakhstan         1957
# 2          Failure          USA         1957
# 3          Success          USA         1958
# 4          Failure          USA         1958
# ...            ...          ...          ...
# 4625       Success          USA         2022
# 4626       Success        China         2022
# 4627       Success          USA         2022
# 4628       Success        China         2022
# 4629       Success        China         2022
#
# [4630 rows x 10 columns]

# %%
loclist=list(df['Location'].str.split(','))

# %%
length=len(loclist)
length
# Out:
# 4630

# %%
country=list([])
launchloc=list([])

# %%
for i in range(length):
    country.append(loclist[i][-1])
    launchloc.append(loclist[i][:-1])

# %%
#adding new column country in dataframe
df['Country']=country

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
df.tail()
# Out:
#         Company                                         Location       Date  \
# 4625     SpaceX          SLC-4E, Vandenberg SFB, California, USA 2022-07-22
# 4626       CASC  LC-101, Wenchang Satellite Launch Center, China 2022-07-24
# 4627     SpaceX       LC-39A, Kennedy Space Center, Florida, USA 2022-07-24
# 4628  CAS Space           Jiuquan Satellite Launch Center, China 2022-07-27
# 4629       CASC     LC-3, Xichang Satellite Launch Center, China 2022-07-29
#
#                 Rocket              Mission RocketStatus      Price  \
# 4625  Falcon 9 Block 5   Starlink Group 3-2       Active   67.00000
# 4626     Long March 5B              Wentian       Active  109.77956
# 4627  Falcon 9 Block 5  Starlink Group 4-25       Active   67.00000
# 4628        Zhongke-1A          Demo Flight       Active  109.77956
# 4629     Long March 2D   Yaogan 35 Group 03       Active   29.75000
#
#      MissionStatus Country  MissionYear
# 4625       Success     USA         2022
# 4626       Success   China         2022
# 4627       Success     USA         2022
# 4628       Success   China         2022
# 4629       Success   China         2022

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4630 entries, 0 to 4629
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          4630 non-null   object
#  1   Location         4630 non-null   object
#  2   Date             4630 non-null   datetime64[ns]
#  3   Rocket           4630 non-null   object
#  4   Mission          4630 non-null   object
#  5   RocketStatus     4630 non-null   object
#  6   Price            4630 non-null   float64
#  7   MissionStatus    4630 non-null   object
#  8   MissionYear      4630 non-null   int32
#  9   Country          4630 non-null   object
#  10  Launch Location  4630 non-null   object
# dtypes: datetime64[ns](1), float64(1), int32(1), object(8)
# memory usage: 379.9+ KB

# %% [markdown]
# # Q.1: How have rocket launches trended across time? Has mission success rate increased?<a id=1></a>

# %% [markdown]
# <font size='5'>Creating Dataframe that contain Successed Mission Launch Counts Over the yaers</font>

# %%
newdf=df[['MissionYear','MissionStatus']]
newdf=newdf.drop(newdf[newdf['MissionStatus'] == 'Failure'].index,axis=0)
newdf=newdf.drop(newdf[newdf['MissionStatus'] == 'Partial Failure'].index,axis=0)
newdf=newdf.drop(newdf[newdf['MissionStatus'] == 'Prelaunch Failure'].index,axis=0)
newdf
# Out:
#       MissionYear MissionStatus
# 0            1957       Success
# 1            1957       Success
# 3            1958       Success
# 6            1958       Success
# 7            1958       Success
# ...           ...           ...
# 4625         2022       Success
# 4626         2022       Success
# 4627         2022       Success
# 4628         2022       Success
# 4629         2022       Success
#
# [4162 rows x 2 columns]

# %%
print(newdf['MissionStatus'].value_counts())
# Out:
# MissionStatus
# Success    4162
# Name: count, dtype: int64

# %%
newdf=newdf.groupby('MissionYear').value_counts()

#convert Series into Dataframe
newdf=pd.DataFrame(newdf)

# %%
#reset index of newdf
newdf.reset_index(inplace=True)

# %%
newdf
# Out:
#     MissionYear MissionStatus  count
# 0          1957       Success      2
# 1          1958       Success      6
# 2          1959       Success      8
# 3          1960       Success     19
# 4          1961       Success     32
# ..          ...           ...    ...
# 61         2018       Success    113
# 62         2019       Success    100
# 63         2020       Success    107
# 64         2021       Success    143
# 65         2022       Success     90
#
# [66 rows x 3 columns]

# %%
#rename column name count to Success Count
newdf.rename(columns={'count':'Success Count'},inplace=True)
newdf
# Out:
#     MissionYear MissionStatus  Success Count
# 0          1957       Success              2
# 1          1958       Success              6
# 2          1959       Success              8
# 3          1960       Success             19
# 4          1961       Success             32
# ..          ...           ...            ...
# 61         2018       Success            113
# 62         2019       Success            100
# 63         2020       Success            107
# 64         2021       Success            143
# 65         2022       Success             90
#
# [66 rows x 3 columns]

# %% [markdown]
# <font size='5'>Creating New dataframe contain year wise failure count</font>

# %%
failuredf=df[['MissionYear','MissionStatus']]
type(failuredf)
# Out:
# pandas.core.frame.DataFrame

# %%
failuredf['MissionStatus'].replace('Prelaunch Failure','Failure',inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5464\2964288626.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   failuredf['MissionStatus'].replace('Prelaunch Failure','Failure',inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5464\2964288626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failuredf['MissionStatus'].replace('Prelaunch Failure','Failure',inplace=True)

# %%
failuredf['MissionStatus'].replace('Partial Failure','Failure',inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5464\2836975795.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   failuredf['MissionStatus'].replace('Partial Failure','Failure',inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5464\2836975795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failuredf['MissionStatus'].replace('Partial Failure','Failure',inplace=True)

# %%
failuredf.loc[failuredf['MissionStatus']=='Partial Failure']
# Out:
# Empty DataFrame
# Columns: [MissionYear, MissionStatus]
# Index: []

# %%
failuredf.drop(failuredf[failuredf['MissionStatus']=='Success'].index,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5464\1628335844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failuredf.drop(failuredf[failuredf['MissionStatus']=='Success'].index,inplace=True)

# %%
failuredf
# Out:
#       MissionYear MissionStatus
# 2            1957       Failure
# 4            1958       Failure
# 5            1958       Failure
# 8            1958       Failure
# 9            1958       Failure
# ...           ...           ...
# 4533         2021       Failure
# 4536         2021       Failure
# 4549         2022       Failure
# 4589         2022       Failure
# 4619         2022       Failure
#
# [468 rows x 2 columns]

# %%
failuredf=failuredf.groupby('MissionYear').value_counts()
failuredf=pd.DataFrame(failuredf)

# %%
failuredf.reset_index(inplace=True)

# %%
failuredf.rename(columns={'count':'FailureCount'},inplace=True)

# %%
failuredf
# Out:
#     MissionYear MissionStatus  FailureCount
# 0          1957       Failure             1
# 1          1958       Failure            22
# 2          1959       Failure            12
# 3          1960       Failure            20
# 4          1961       Failure            20
# ..          ...           ...           ...
# 61         2018       Failure             4
# 62         2019       Failure             9
# 63         2020       Failure            12
# 64         2021       Failure            14
# 65         2022       Failure             3
#
# [66 rows x 3 columns]

# %%
#merge failuredf and newdf 
missiondf=newdf.merge(failuredf,left_on='MissionYear',right_on='MissionYear')
missiondf
# Out:
#     MissionYear MissionStatus_x  Success Count MissionStatus_y  FailureCount
# 0          1957         Success              2         Failure             1
# 1          1958         Success              6         Failure            22
# 2          1959         Success              8         Failure            12
# 3          1960         Success             19         Failure            20
# 4          1961         Success             32         Failure            20
# ..          ...             ...            ...             ...           ...
# 61         2018         Success            113         Failure             4
# 62         2019         Success            100         Failure             9
# 63         2020         Success            107         Failure            12
# 64         2021         Success            143         Failure            14
# 65         2022         Success             90         Failure             3
#
# [66 rows x 5 columns]

# %%
missiondf.drop(columns={'MissionStatus_x','MissionStatus_y'},inplace=True)

# %%
missiondf
# Out:
#     MissionYear  Success Count  FailureCount
# 0          1957              2             1
# 1          1958              6            22
# 2          1959              8            12
# 3          1960             19            20
# 4          1961             32            20
# ..          ...            ...           ...
# 61         2018            113             4
# 62         2019            100             9
# 63         2020            107            12
# 64         2021            143            14
# 65         2022             90             3
#
# [66 rows x 3 columns]

# %%
sns.set_theme(style='dark')

# %%
#plotting success count over the year
sns.lineplot(data=missiondf,x='MissionYear',y='Success Count')
plt.grid()

# %%
#plotting success count over the year
sns.lineplot(data=missiondf,x='MissionYear',y='FailureCount')
plt.grid()

# %%
#setting up the figure size of the plot
plt.figure(figsize=(10,5))

#plotting successed mission counts over the year
sns.lineplot(data=missiondf,x='MissionYear',y='Success Count',label="Successed Missions",color='b')

#plotting Failed mission counts over the year
sns.lineplot(data=missiondf,x='MissionYear',y='FailureCount',label="Failed Missions",color='r')

plt.xlabel('Space Mission Years')
plt.ylabel('Number of Space Missions')

#title for the plot
plt.title("Successed and Failed Mission Launch over the Years")

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2 plt.figure(figsize=(10,5))
#       4 #plotting successed mission counts over the year
# ----> 5 sns.lineplot(data=missiondf,x='MissionYear',y='Success Count',label="Successed Missions",color='b')
#       7 #plotting Failed mission counts over the year
#       8 sns.lineplot(data=missiondf,x='MissionYear',y='FailureCount',label="Failed Missions",color='r')
#
# NameError: name 'missiondf' is not defined

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=newdf,x='MissionYear',y='Success Count',color='Orange',legend='auto')
plt.title('Success Rate Bar Plot Over The Year')
plt.xlabel('Mission Lanching Years')
plt.ylabel('Counts of Missions')
plt.xticks(rotation=90,color='Red')
plt.grid(axis='y')
plt.show()

# %%
#initializing matplotlib figure
#f,ax = plt.figure(figsize=(6,15))
plt.figure(figsize=(14,10))

#plot the success counts
sns.set_color_codes('pastel')
sns.barplot(data=missiondf,x='MissionYear',y='Success Count',label='Successed Mission',color='b')

#plot the failure mission counts
sns.set_color_codes('muted')
sns.barplot(data=missiondf,x='MissionYear',y='FailureCount',label='Failed Mission',color='r',alpha=0.4)

plt.xticks(rotation=90,color='orange')
plt.show()

#ax.legend9(ncol=2,loc='upper right',frameon=True)
#ax.set()
#sns.despine(left=True,bottom=True)

# %%
#initializing matplotlib figure
f, ax = plt.subplots(figsize=(13,14))
#plt.figure(figsize=(15,15))

#plot the success counts
sns.set_color_codes('pastel')
sns.barplot(data=missiondf,x='Success Count',y='MissionYear',label='Successed Mission',color='b',orient='h')

#plot the failure mission counts
sns.set_color_codes('muted')
sns.barplot(data=missiondf,x='FailureCount',y='MissionYear',label='Failed Mission',color='r',alpha=0.4,orient='h')

#plt.xticks(rotation=90,color='orange')

ax.legend(ncol=1,loc='upper right',frameon=True)
ax.set(xlim=(0,150),ylabel="",xlabel="Successed and failed Missions Count")
sns.despine(left=True,bottom=True)

# %% [markdown]
# # Q.2:Which countries have had the most successful space missions? Has it always been that way?** <a id=2></a>

# %%
successed_country=df[['Country','MissionStatus']]

# %%
successed_country.drop(successed_country[successed_country['MissionStatus'] == 'Failure'].index,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8424\3497219282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successed_country.drop(successed_country[successed_country['MissionStatus'] == 'Failure'].index,inplace=True)

# %%
successed_country.drop(successed_country[successed_country['MissionStatus'] == 'Partial Failure'].index,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8424\1612368928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successed_country.drop(successed_country[successed_country['MissionStatus'] == 'Partial Failure'].index,inplace=True)

# %%
successed_country.drop(successed_country[successed_country['MissionStatus'] == 'Prelaunch Failure'].index,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8424\414852498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successed_country.drop(successed_country[successed_country['MissionStatus'] == 'Prelaunch Failure'].index,inplace=True)

# %%
successed_country
# Out:
#           Country MissionStatus
# 0      Kazakhstan       Success
# 1      Kazakhstan       Success
# 3             USA       Success
# 6             USA       Success
# 7             USA       Success
# ...           ...           ...
# 4625          USA       Success
# 4626        China       Success
# 4627          USA       Success
# 4628        China       Success
# 4629        China       Success
#
# [4162 rows x 2 columns]

# %%
successed_country=successed_country.groupby(['Country']).count()

# %%
successed_country
# Out:
#                            MissionStatus
# Country
# Australia                              3
# Barents Sea                            2
# China                                335
# France                               299
# Gran Canaria                           2
# India                                 68
# Iran                                   6
# Israel                                 9
# Japan                                117
# Kazakhstan                           625
# Kenya                                  9
# New Zealand                           25
# North Korea                            2
# Pacific Ocean                         33
# Russia                              1323
# Shahrud Missile Test Site              1
# South Korea                            2
# USA                                 1298
# Yellow Sea                             3

# %%
successed_country.rename(columns={'MissionStatus':'Successed Missions'},inplace=True)

# %%
successed_country.sort_values(by='Successed Missions',ascending=False,inplace=True)

# %%
successed_country
# Out:
#                            Successed Missions
# Country
# Russia                                   1323
# USA                                      1298
# Kazakhstan                                625
# China                                     335
# France                                    299
# Japan                                     117
# India                                      68
# Pacific Ocean                              33
# New Zealand                                25
# Israel                                      9
# Kenya                                       9
# Iran                                        6
# Australia                                   3
# Yellow Sea                                  3
# North Korea                                 2
# Barents Sea                                 2
# South Korea                                 2
# Gran Canaria                                2
# Shahrud Missile Test Site                   1

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=successed_country,x=successed_country.index,y='Successed Missions',color='orange')
plt.title('Successed Space Missions BY Countries')
plt.xlabel('Countries')
plt.ylabel('Number of Successfull Missions')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # Q.3:Which rocket has been used for the most space missions? Is it still active? <a id=3></a>

# %%
rockets=df[['Rocket','RocketStatus']]

# %%
rockets=rockets.groupby(['Rocket']).value_counts()

# %%
rockets=pd.DataFrame(rockets)

# %%
rockets.sort_values(by='count')
# Out:
#                                   count
# Rocket              RocketStatus
# Zoljanah            Active            1
# Delta II 7920H      Retired           1
# Delta II 7920-8     Retired           1
# Delta II 7920-10L   Retired           1
# Delta II 7426       Retired           1
# ...                                 ...
# Soyuz U             Retired         125
# Cosmos-2I (63SM)    Retired         126
# Molniya-M /Block ML Retired         128
# Voskhod             Retired         299
# Cosmos-3M (11K65M)  Retired         446
#
# [370 rows x 1 columns]

# %%
rockets.rename(columns={'count' : 'Total Missions'},inplace=True)

# %%
rockets.sort_values(by='Total Missions',ascending=False,inplace=True)

# %%
rockets.reset_index(inplace=True)

# %%
plt.figure(figsize=(15,15))
plt.xlabel('Name of Rockets')
sns.barplot(data=rockets.head(16),x='Rocket',y='Total Missions',color='orange')
plt.xlabel('Name of Rockets')
plt.ylabel('Total Missions By Rocket')
plt.xticks(rotation=90,color='red')
plt.title('Total Missions By Rockets')
plt.grid()
plt.show()

# %%
rockets[rockets['RocketStatus']=='Retired']
# Out:
#      index               Rocket RocketStatus  Total Missions
# 0       84   Cosmos-3M (11K65M)      Retired             446
# 1      357              Voskhod      Retired             299
# 2      210  Molniya-M /Block ML      Retired             128
# 3       82     Cosmos-2I (63SM)      Retired             126
# 4      299              Soyuz U      Retired             125
# ..     ...                  ...          ...             ...
# 364    249      Redstone Sparta      Retired               1
# 365    126      Energiya/Polyus      Retired               1
# 366    125       Energiya/Buran      Retired               1
# 367     79       Conestoga-1620      Retired               1
# 368     86         Delta 3920-8      Retired               1
#
# [267 rows x 4 columns]

# %%
rockets[rockets['RocketStatus']=='Active']
# Out:
#      index            Rocket RocketStatus  Total Missions
# 6      135  Falcon 9 Block 5       Active             111
# 10      19      Ariane 5 ECA       Active              80
# 15     175     Long March 2D       Active              44
# 16     171     Long March 2C       Active              43
# 18     184   Long March 3B/E       Active              41
# ..     ...               ...          ...             ...
# 347    122          Electron       Active               1
# 359    312      Super Stripy       Active               1
# 360    245          Proton-M       Active               1
# 363    127           Epsilon       Active               1
# 369    369          Zoljanah       Active               1
#
# [103 rows x 4 columns]

# %% [markdown]
# # Q.4: Are there any patterns you can notice with the launch locations? <a id=3></a>

# %%
location=df[['Location','MissionStatus']]

# %%
location['Location'].value_counts()
# Out:
# Location
# Site 31/6, Baikonur Cosmodrome, Kazakhstan               251
# Site 132/1, Plesetsk Cosmodrome, Russia                  216
# Site 43/4, Plesetsk Cosmodrome, Russia                   211
# Site 41/1, Plesetsk Cosmodrome, Russia                   198
# Site 1/5, Baikonur Cosmodrome, Kazakhstan                193
#                                                         ...
# Pad A, Boca Chica, Texas, USA                              1
# K-496 Submarine, Barents Sea Launch Area, Barents Sea      1
# Launch Plateform, Shahrud Missile Test Site                1
# K-84 Submarine, Barents Sea Launch Area, Barents Sea       1
# LC-9A, Taiyuan Satellite Launch Center, China              1
# Name: count, Length: 158, dtype: int64

# %%
location.groupby(['Location']).value_counts()
# Out:
# Location                                                 MissionStatus
# Blue Origin Launch Site, West Texas, Texas, USA          Success            12
# Brigitte, Hammaguir, Algeria, France                     Success             3
#                                                          Partial Failure     1
# Cosmic Girl, Mojave Air and Space Port, California, USA  Success             4
#                                                          Failure             1
#                                                                             ..
# VMS Eve, Spaceport America, New Mexico, USA              Success             2
#                                                          Partial Failure     1
# Vertical Launch Area, Spaceport America, New Mexico      Partial Failure     3
#                                                          Failure             1
# Xichang Satellite Launch Center, China                   Success             2
# Name: count, Length: 298, dtype: int64

# %%
successed=location[location['MissionStatus'] == 'Success']

# %%
successed=successed.groupby('Location').value_counts()

# %%
successed=pd.DataFrame(successed)

# %%
successed.sort_values(by='count',ascending=False,inplace=True)

# %%
successed.reset_index(inplace=True)

# %%
successed.rename(columns={'count':'TotalSuccessMissions'},inplace=True)

# %%
successed['TotalSuccessMissions'].sum()
# Out:
# 4162

# %%
partial_fail=location[location['MissionStatus'] == 'Partial Failure']

# %%
partial_fail=partial_fail.groupby('Location').value_counts()

# %%
partial_fail=pd.DataFrame(partial_fail)

# %%
partial_fail['count'].sum()
# Out:
# 147

# %%
counts.transpose().plot(kind='bar',stacked=False)
plt.show()
